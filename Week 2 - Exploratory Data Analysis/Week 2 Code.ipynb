# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students = pd.read_csv('C:/Users/Public/Downloads/AI_Internship_Week2.csv')
students.head()
# Out:
#                              Profile Id Learner SignUp DateTime  \
# 0  00628747-9775-4a85-a179-4d5007ccb8b7     2023-05-01 05:29:16
# 1  019c7a24-b72f-490c-ae28-ee3bf85eab4d     2023-05-31 07:11:04
# 2  01ca6306-aa78-4a5a-9634-d546723751a7     2023-03-20 16:36:30
# 3  01ffe907-881a-4fdb-ae33-650cc2de218b     2023-05-11 03:40:33
# 4  021fd9d4-271a-41c2-9fab-602c5ffa264c     2023-01-28 21:56:47
#
#                                     Opportunity Name Opportunity Category  \
# 0  Career Essentials: Getting Started with Your P...               Course
# 1  Career Essentials: Getting Started with Your P...               Course
# 2  Career Essentials: Getting Started with Your P...               Course
# 3  Career Essentials: Getting Started with Your P...               Course
# 4  Career Essentials: Getting Started with Your P...               Course
#
#   Opportunity End Date First Name    Last Name Date of Birth  Gender  \
# 0  2024-06-29 18:52:39   Poojitha      Bembadi    2000-08-16  Female
# 1  2024-06-29 18:52:39    Fardeen       Shroff    2001-09-09    Male
# 2  2024-06-29 18:52:39  SIDDHARTH      RAJAWAT    2005-12-22    Male
# 3  2024-06-29 18:52:39   Vanshika     Varshney    1998-06-26  Female
# 4  2024-06-29 18:52:39   Precious  Christopher    1997-06-30  Female
#
#    Mobile Number  ... SignUp Month SignUp Year Time in Opportunity  \
# 0   919381442895  ...          5.0      2023.0          604.015278
# 1   919820278783  ...          5.0      2023.0          604.015278
# 2   919870953256  ...          3.0      2023.0          604.015278
# 3   919549824344  ...          5.0      2023.0          604.015278
# 4  2349091771856  ...          1.0      2023.0          604.015278
#
#   Time in Opportunity (Days)  Age of Learner x Time in Opportunity  \
# 0                      604.0                               14496.0
# 1                      604.0                               13892.0
# 2                      604.0                               10872.0
# 3                      604.0                               15704.0
# 4                      604.0                               16308.0
#
#   Engagement Score SignUp Day of Week Last Engagement Date  \
# 0       248.806111             Monday  2022-11-03 18:30:39
# 1       248.506111          Wednesday  2022-11-03 18:30:39
# 2       247.006111             Monday  2022-11-03 18:30:39
# 3       249.406111           Thursday  2022-11-03 18:30:39
# 4       249.706111           Saturday  2022-11-03 18:30:39
#
#   Days Since Last Engagement High Engagement
# 0                      178.0               1
# 1                      208.0               1
# 2                      136.0               1
# 3                      188.0               1
# 4                       86.0               1
#
# [5 rows x 36 columns]

# %%
# 1. Count the number of NaN values in each column
empty_per_column = students.isna().sum()

# 2. Filter columns that have at least one NaN
columns_with_empty = empty_per_column[empty_per_column > 0]

# 3. Total number of NaN values across the entire dataframe
total_empty = students.isna().sum().sum()

print(f"Columns with empty entries:\n{columns_with_empty}")
print(f"Total number of empty entries: {total_empty}")
# Out:
# Columns with empty entries:
# Series([], dtype: int64)
# Total number of empty entries: 0

# %% [markdown]
# There are 0 empty rows, so we can just start working with the other EDA steps.

# %%
# Statistical information:

students.describe()
# Out:
#        Mobile Number      Zip Code  Status Code  Age of Learner  \
# count   2.024000e+03  2.024000e+03  2024.000000     2024.000000
# mean    2.311948e+12  3.084315e+05  1072.129447       24.295455
# std     6.618342e+12  2.024375e+06     9.357039        4.924407
# min     9.112340e+05  1.000000e+00  1050.000000       13.000000
# 25%     1.618602e+10  6.310300e+04  1070.000000       22.000000
# 50%     9.180748e+11  9.281500e+04  1070.000000       24.000000
# 75%     9.199302e+11  5.000580e+05  1080.000000       26.000000
# max     8.800199e+13  8.921808e+07  1120.000000       56.000000
#
#        Engagement Duration  SignUp Month  SignUp Year  Time in Opportunity  \
# count          2024.000000   2024.000000  2024.000000          2024.000000
# mean              0.453127      5.803360  2023.175889           395.755613
# std               0.212507      3.177384     0.380820           284.151325
# min               0.000000      1.000000  2023.000000            -6.875000
# 25%               0.298246      3.000000  2023.000000            63.603634
# 50%               0.479950      6.000000  2023.000000           604.015278
# 75%               0.617794      8.000000  2023.000000           604.015278
# max               1.000000     12.000000  2024.000000           913.000000
#
#        Time in Opportunity (Days)  Age of Learner x Time in Opportunity  \
# count                 2024.000000                           2024.000000
# mean                   395.377964                           9587.902668
# std                    284.488948                           7348.799509
# min                     -7.000000                           -210.000000
# 25%                     63.000000                           1386.000000
# 50%                    604.000000                          12080.000000
# 75%                    604.000000                          15100.000000
# max                    913.000000                          51128.000000
#
#        Engagement Score  Days Since Last Engagement  High Engagement
# count       2024.000000                 2024.000000      2024.000000
# mean         165.590882                   64.412549         0.539032
# std          113.651149                  196.395772         0.498597
# min            3.550000                 -512.000000         0.000000
# 25%           31.874722                  -76.000000         0.000000
# 50%          247.306111                   65.000000         1.000000
# 75%          249.106111                  223.000000         1.000000
# max          382.000000                  475.000000         1.000000

# %% [markdown]
# ## Graphical Analysis

# %% [markdown]
# ### Gender Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gender distribution
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=students, palette='coolwarm')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Tells us that there are slightly more Males than Females in our dataset.

# %% [markdown]
# ### Age distribution

# %%
# Age distribution
plt.figure(figsize=(8,6))
sns.histplot(students['Age of Learner'], bins=20, kde=True, color='green')
plt.title('Age of Learner Distribution')
plt.xlabel('Age of Learner')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Corelation between Age and Engagement Score

# %% [markdown]
# Tells us that most users in our dataset have an age between 20 and 27, with the highest being 22 and 23

# %%
# Scatter plot of Age vs. Engagement Score
plt.figure(figsize=(8,6))
sns.scatterplot(x='Age of Learner', y='Engagement Score', data=students, hue='Gender', palette='coolwarm')
plt.title('Age of Learner vs Engagement Score')
plt.xlabel('Age of Learner')
plt.ylabel('Engagement Score')
plt.show()

# %% [markdown]
# **Age distribution:** The age range of the learners is from approximately 15 to 50 years old.
# **Engagement score distribution:** The engagement scores range from 0 to around 350, with a clustering of scores around 200-250.
#
# **Gender differences:**
# **Male:** There seems to be a slight trend of higher engagement scores among males, especially in the younger age groups.
# **Female:** Female engagement scores are more spread out, with a slightly higher concentration in the lower engagement ranges.
# Other: The "Other" and "Don't want to specify" categories have limited data points, making it difficult to draw conclusions about their engagement patterns.

# %%
students.dtypes
# Out:
# Profile Id                               object
# Learner SignUp DateTime                  object
# Opportunity Name                         object
# Opportunity Category                     object
# Opportunity End Date                     object
# First Name                               object
# Last Name                                object
# Date of Birth                            object
# Gender                                   object
# Mobile Number                             int64
# Address Line 1                           object
# City                                     object
# State                                    object
# Country                                  object
# Zip Code                                  int64
# Institution Name                         object
# Graduation Date                          object
# Current Student Status                   object
# Current/Intended Major                   object
# Entry created at                         object
# Status Description                       object
# Status Code                               int64
# Apply Date                               object
# Opportunity Start Date                   object
# Age of Learner                            int64
# Engagement Duration                     float64
# SignUp Month                            float64
# SignUp Year                             float64
# Time in Opportunity                     float64
# Time in Opportunity (Days)              float64
# Age of Learner x Time in Opportunity    float64
# Engagement Score                        float64
# SignUp Day of Week                       object
# Last Engagement Date                     object
# Days Since Last Engagement              float64
# High Engagement                           int64
# dtype: object

# %% [markdown]
# ### Oppurtunity (Days) Distribution

# %% [markdown]
# Explore how long learners have been engaged in the opportunity using a histogram.

# %%
students['Days Since Last Engagement'].head()
# Out:
# 0    178.0
# 1    208.0
# 2    136.0
# 3    188.0
# 4     86.0
# Name: Days Since Last Engagement, dtype: float64

# %%
# Time in Opportunity distribution
plt.figure(figsize=(8,6))
sns.histplot(students['Time in Opportunity (Days)'], bins=20, kde=True, color='purple')
plt.title('Distribution of Time in Opportunity (Days)')
plt.xlabel('Time in Opportunity (Days)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Literal Bruh moment, tells us nothing about anything here.
#
# - Users were initially engaged in first 70-80 days.
# - Then a spike at 450ish day mark.
# - Then after 600 days which is very surprising, should not have happened. Like why would a user be engaging for 600 days in 1 month internship.
# - Then it settles down at 800 day mark.

# %% [markdown]
# ### Engagement Score by SignUp Month

# %%
# Engagement Score by SignUp Month
plt.figure(figsize=(8,6))
sns.boxplot(x='SignUp Month', y='Engagement Score', data=students, palette='Set1')
plt.title('Engagement Score by SignUp Month')
plt.xlabel('SignUp Month')
plt.ylabel('Engagement Score')
plt.show()

# %% [markdown]
# - Month 7 has one of the highest median engagement scores, suggesting users signing up in this month tend to have higher engagement.
# - Months 1 and 4 have the largest variability, as their engagement scores are spread over a wider range.
# - Some months have a higher number of outliers (e.g., months 4 and 6), indicating that while most users in these months had similar engagement, a few users exhibited much higher or lower engagement.

# %% [markdown]
# ### Sign-up day of the week

# %%
# Plotting the number of sign-ups in different days of a week
plt.figure(figsize=(9,5))
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.countplot(x='SignUp Day of Week', data=students, order=day_order, palette='dark')
plt.title('SignUp Day of Week')
plt.xlabel('Days of Week')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# ### Current Student Status

# %%
data = {
    'Current Student Status': ['Enrolled', 'Graduated', 'Enrolled', 'Dropped Out', 'Enrolled', 'Graduated', 'Enrolled']
}
students = pd.DataFrame(data)

# Count the occurrences of each status
status_counts = students['Current Student Status'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab10.colors)
plt.title('Current Student Status Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Signup Growth Over Time

# %%
signups_by_month = students.groupby(students['SignUp Month'])['Profile Id'].count()
signups_by_month.plot(kind='bar', figsize=(10, 6))
plt.title('Signup Growth Over Time')
plt.xlabel('Signup Month')
plt.ylabel('Number of Signups')
plt.show()

# %% [markdown]
# ### Signup Seasonality

# %%
signup_heatmap = students.groupby(['SignUp Year', 'SignUp Month'])['Profile Id'].count().unstack()
sns.heatmap(signup_heatmap, cmap='Blues', annot=True, fmt='g')
plt.title('Signup Seasonality Heatmap')
plt.xlabel('Signup Month')
plt.ylabel('Signup Year')
plt.show()

# %% [markdown]
# ### Gender vs Engagement Score

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=students['Gender'], y=students['Engagement Score'], hue=students['Gender'],palette="Set3")
plt.title("Gender vs Engagement Score")
plt.xlabel("Gender")
plt.ylabel("Engagement Score")
plt.show()

# %% [markdown]
# ### Days Since Last Engagement vs. Re-Engagement

# %%
# Days Since Last Engagement vs. Re-Engagement
import seaborn as sns

sns.histplot(data = students, x='Days Since Last Engagement', hue='High Engagement', multiple='stack')
plt.title('Days Since Last Engagement for High vs. Low Engagement')
plt.xlabel('Days Since Last Engagement')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Corelation Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(students.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %%
students.corr()
# Out:
#                                       Mobile Number  Zip Code  Status Code  \
# Mobile Number                              1.000000  0.021622     0.059215
# Zip Code                                   0.021622  1.000000     0.087880
# Status Code                                0.059215  0.087880     1.000000
# Age of Learner                             0.058195 -0.029658    -0.066871
# Engagement Duration                       -0.029288 -0.012436    -0.228597
# month                                     -0.016069  0.000012    -0.279363
# year                                      -0.021328 -0.021710    -0.030253
# Time in Opportunity                        0.041471  0.017283     0.346912
# Time in Opportunity (Days)                 0.041495  0.017295     0.346879
# Age of Learner x Time in Opportunity       0.057086  0.005982     0.309540
# Engagement Score                           0.042231  0.016899     0.346072
# Days Since Last Engagement                 0.051192  0.012841     0.274312
# High Engagement                            0.047353  0.022245     0.322817
# Month Since SignUp                         0.040258  0.026882     0.278073
#
#                                       Age of Learner  Engagement Duration  \
# Mobile Number                               0.058195            -0.029288
# Zip Code                                   -0.029658            -0.012436
# Status Code                                -0.066871            -0.228597
# Age of Learner                              1.000000             0.036688
# Engagement Duration                         0.036688             1.000000
# month                                      -0.017104            -0.019096
# year                                        0.042390             0.042107
# Time in Opportunity                        -0.012849            -0.686209
# Time in Opportunity (Days)                 -0.012844            -0.686316
# Age of Learner x Time in Opportunity        0.252781            -0.638451
# Engagement Score                            0.000149            -0.685789
# Days Since Last Engagement                 -0.021448            -0.903846
# High Engagement                             0.030936            -0.654012
# Month Since SignUp                         -0.037777            -0.035711
#
#                                          month      year  Time in Opportunity  \
# Mobile Number                        -0.016069 -0.021328             0.041471
# Zip Code                              0.000012 -0.021710             0.017283
# Status Code                          -0.279363 -0.030253             0.346912
# Age of Learner                       -0.017104  0.042390            -0.012849
# Engagement Duration                  -0.019096  0.042107            -0.686209
# month                                 1.000000 -0.598073            -0.110145
# year                                 -0.598073  1.000000            -0.192866
# Time in Opportunity                  -0.110145 -0.192866             1.000000
# Time in Opportunity (Days)           -0.110082 -0.192994             1.000000
# Age of Learner x Time in Opportunity -0.107388 -0.172476             0.944790
# Engagement Score                     -0.110376 -0.192331             0.999916
# Days Since Last Engagement            0.018960  0.063939             0.677223
# High Engagement                      -0.124330 -0.158532             0.885903
# Month Since SignUp                   -0.120425 -0.723586             0.333759
#
#                                       Time in Opportunity (Days)  \
# Mobile Number                                           0.041495
# Zip Code                                                0.017295
# Status Code                                             0.346879
# Age of Learner                                         -0.012844
# Engagement Duration                                    -0.686316
# month                                                  -0.110082
# year                                                   -0.192994
# Time in Opportunity                                     1.000000
# Time in Opportunity (Days)                              1.000000
# Age of Learner x Time in Opportunity                    0.944787
# Engagement Score                                        0.999915
# Days Since Last Engagement                              0.677379
# High Engagement                                         0.886094
# Month Since SignUp                                      0.333864
#
#                                       Age of Learner x Time in Opportunity  \
# Mobile Number                                                     0.057086
# Zip Code                                                          0.005982
# Status Code                                                       0.309540
# Age of Learner                                                    0.252781
# Engagement Duration                                              -0.638451
# month                                                            -0.107388
# year                                                             -0.172476
# Time in Opportunity                                               0.944790
# Time in Opportunity (Days)                                        0.944787
# Age of Learner x Time in Opportunity                              1.000000
# Engagement Score                                                  0.948154
# Days Since Last Engagement                                        0.629040
# High Engagement                                                   0.848666
# Month Since SignUp                                                0.306128
#
#                                       Engagement Score  \
# Mobile Number                                 0.042231
# Zip Code                                      0.016899
# Status Code                                   0.346072
# Age of Learner                                0.000149
# Engagement Duration                          -0.685789
# month                                        -0.110376
# year                                         -0.192331
# Time in Opportunity                           0.999916
# Time in Opportunity (Days)                    0.999915
# Age of Learner x Time in Opportunity          0.948154
# Engagement Score                              1.000000
# Days Since Last Engagement                    0.677000
# High Engagement                               0.886378
# Month Since SignUp                            0.333295
#
#                                       Days Since Last Engagement  \
# Mobile Number                                           0.051192
# Zip Code                                                0.012841
# Status Code                                             0.274312
# Age of Learner                                         -0.021448
# Engagement Duration                                    -0.903846
# month                                                   0.018960
# year                                                    0.063939
# Time in Opportunity                                     0.677223
# Time in Opportunity (Days)                              0.677379
# Age of Learner x Time in Opportunity                    0.629040
# Engagement Score                                        0.677000
# Days Since Last Engagement                              1.000000
# High Engagement                                         0.658520
# Month Since SignUp                                     -0.095528
#
#                                       High Engagement  Month Since SignUp
# Mobile Number                                0.047353            0.040258
# Zip Code                                     0.022245            0.026882
# Status Code                                  0.322817            0.278073
# Age of Learner                               0.030936           -0.037777
# Engagement Duration                         -0.654012           -0.035711
# month                                       -0.124330           -0.120425
# year                                        -0.158532           -0.723586
# Time in Opportunity                          0.885903            0.333759
# Time in Opportunity (Days)                   0.886094            0.333864
# Age of Learner x Time in Opportunity         0.848666            0.306128
# Engagement Score                             0.886378            0.333295
# Days Since Last Engagement                   0.658520           -0.095528
# High Engagement                              1.000000            0.303447
# Month Since SignUp                           0.303447            1.000000

# %% [markdown]
# ### Current Student Status by Opportunity Category:

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Opportunity Category', hue='Current Student Status', data=students, palette='Set1')
plt.title('Current Student Status by Opportunity Category')
plt.xlabel('Opportunity Category')
plt.ylabel('Count of Learners')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Application Status by Opportunity:

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Opportunity Category', hue='Status Description', data=students, palette='Set1')
plt.title('Application Status by Opportunity Category')
plt.xlabel('Opportunity Category')
plt.ylabel('Application Status Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Country-wise Learner Distribution

# %%
plt.figure(figsize=(10,6))
top_countries = students['Country'].value_counts().nlargest(10)
sns.barplot(x=top_countries.index, y=top_countries.values, palette='Set3')
plt.title('Top 10 Countries by Learner Count')
plt.xlabel('Country')
plt.ylabel('Number of Learners')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Principal Component Analysis (PCA) for Dimensionality Reduction

# %% [markdown]
# Reduce the dataset's dimensions while preserving variance, helping to visualize patterns and groupings in high-dimensional data.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(students[['Engagement Score', 'Time in Opportunity (Days)', 'Days Since Last Engagement']])

plt.figure(figsize=(8,6))
plt.scatter(pca_data[:,0], pca_data[:,1], c='blue', alpha=0.6)
plt.title('PCA of Numeric Features')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# ### Clustering Analysis (K-Means)

# %% [markdown]
# Group learners into clusters based on their behaviors and attributes, such as Engagement Score, Time in Opportunity, and Days Since Last Engagement.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)  # Assume 3 clusters
students_clustered = students[['Engagement Score', 'Time in Opportunity (Days)', 'Days Since Last Engagement']].dropna()
kmeans.fit(students_clustered)

plt.figure(figsize=(8,6))
plt.scatter(students_clustered['Engagement Score'], students_clustered['Time in Opportunity (Days)'], 
            c=kmeans.labels_, cmap='viridis')
plt.title('K-Means Clustering of Students')
plt.xlabel('Engagement Score')
plt.ylabel('Time in Opportunity (Days)')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\user\anaconda3\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")

# %% [markdown]
# Cluster 1 (Purple): Students with high engagement scores and a long time in opportunity. These students are likely highly engaged and have been exposed to the learning opportunity for a significant period.
#
# Cluster 2 (Yellow): Students with moderate engagement scores and a moderate time in opportunity. These students show some engagement but may not be as deeply involved as the students in Cluster 1.
#
# Cluster 3 (Teal): Students with low engagement scores and a short time in opportunity. These students are likely less engaged and have not had much exposure to the learning opportunity.

# %% [markdown]
# Identifying High-Engagement Students: Cluster 1 can be a target group for further engagement strategies or advanced learning opportunities.
#
# Identifying At-Risk Students: Cluster 3 may require additional support or interventions to improve their engagement and learning outcomes.
#
# Understanding Engagement Patterns: The clustering can help educators understand how different factors (time and engagement) influence student outcomes.

# %% [markdown]
# ### Cohort Analysis

# %% [markdown]
# Cohort analysis is a powerful technique that helps businesses understand how groups of users, known as cohorts, behave over time. By grouping users based on shared characteristics like acquisition date or specific behaviors, businesses can track patterns and trends in their actions.

# %% [markdown]
# Track groups of learners based on their signup month (or any other variable) to see how their behavior (e.g., Engagement Score) changes over time.

# %%
import pandas as pd
from datetime import datetime

# Sample dataset structure (replace this with actual data)
# students = pd.read_csv('your_data.csv') # Load your actual data here

# Ensure columns are correctly renamed and processed
students = students.rename(columns={'SignUp Year': 'year', 'SignUp Month': 'month'})

# Combine 'year' and 'month' into a 'Cohort' column
students['Cohort'] = students['year'].astype(str) + '-' + students['month'].astype(str)

# Now create 'SignUp Date' by assigning the day manually (1st of the month)
students['SignUp Date'] = pd.to_datetime(students[['year', 'month']].assign(day=1))

# Calculate 'Month Since SignUp' (difference between current date and signup date in months)
current_date = pd.to_datetime(datetime.now().date())
students['Month Since SignUp'] = ((current_date.year - students['SignUp Date'].dt.year) * 12 + 
                                  (current_date.month - students['SignUp Date'].dt.month))

# Check if 'Cohort' column is created successfully
print(students[['Cohort', 'SignUp Date', 'Month Since SignUp']].head())  # Debugging step

# Perform the cohort analysis (grouping by 'Cohort' and 'Month Since SignUp')
cohort_pivot = students.groupby(['Cohort', 'Month Since SignUp'])['Engagement Score'].mean().unstack()

# Plot the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(cohort_pivot, cmap='Blues', annot=True, fmt='.1f')
plt.title('Cohort Analysis: Engagement Score by Signup Month')
plt.show()
# Out:
#        Cohort SignUp Date  Month Since SignUp
# 0  2023.0-5.0  2023-05-01                  17
# 1  2023.0-5.0  2023-05-01                  17
# 2  2023.0-3.0  2023-03-01                  19
# 3  2023.0-5.0  2023-05-01                  17
# 4  2023.0-1.0  2023-01-01                  21
# C:\Users\user\anaconda3\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ### Partial Dependence Plot (Machine Learning Context):

# %% [markdown]
# Visualize how specific features affect the predicted outcome (e.g., Engagement Score), using a trained machine learning model.

# %%
from sklearn.inspection import PartialDependenceDisplay
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# Train a basic model
model = RandomForestRegressor()
X = students[['Time in Opportunity (Days)', 'Days Since Last Engagement', 'Age of Learner']]
y = students['Engagement Score']
model.fit(X, y)

# Plot Partial Dependence using PartialDependenceDisplay
features = ['Time in Opportunity (Days)', 'Age of Learner']
PartialDependenceDisplay.from_estimator(model, X, features=features)

# Show the plot
plt.show()

# %% [markdown]
# Time spent in an opportunity is a significant factor in predicting engagement. Longer exposure to an opportunity seems to correlate with higher engagement scores.
# Age of the learner appears to have a negligible impact on engagement. The model suggests that age is not a strong predictor of engagement in this context.

# %% [markdown]
# ### Pair Plot (Scatter Matrix):

# %% [markdown]
# A pair plot allows you to see the distribution of a variable in your dataset and the relationships between variables. It’s useful for seeing how features interact with one another.

# %%
import seaborn as sns

# Pair plot of selected features
sns.pairplot(students[['Time in Opportunity (Days)', 'Engagement Score', 'Days Since Last Engagement']])
plt.show()

# %% [markdown]
# Engagement Score:
# This is the original time series data, showing the engagement score over time. It appears to have some fluctuations and patterns.
#
# Trend:
# This component captures the long-term direction of the engagement score. It seems to have a slight upward trend overall.
#
# Seasonal:
# This component shows any recurring patterns within the data, such as seasonal variations. In this case, there might be some minor seasonal fluctuations, but they are not very pronounced.
#
# Residual:
# The residual component represents the random noise or unexplained variation in the data. It shows the differences between the actual data points and the sum of the trend and seasonal components.
#
# Overall, the graph suggests that the engagement score has a slight upward trend over time, with some minor seasonal variations and random fluctuations.

# %% [markdown]
# ## Hypothesis Development

# %% [markdown]
# ### Corelation analysis:
# **Hypothesis: Engagement scores decline as the time since signup increases.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation
correlation = students['Month Since SignUp'].corr(students['Engagement Score'])
print(f"Correlation between Months Since Signup and Engagement Score: {correlation}")

# Visualize the relationship
sns.regplot(x='Month Since SignUp', y='Engagement Score', data=students)
plt.title('Relationship between Months Since Signup and Engagement Score')
plt.show()
# Out:
# Correlation between Months Since Signup and Engagement Score: 0.33329541418600667

# %% [markdown]
# The graph and the provided correlation coefficient contradict the hypothesis. The graph shows a positive correlation, indicating that engagement scores tend to increase as the time since signup increases, not decline.
#
# Therefore, the data does not support the hypothesis.

# %% [markdown]
# ### Cohort Analysis
#
# Hypothesis: Students who are highly engaged in the first 30 days are more likely to remain active long-term.

# %%
# Divide students into high and low initial engagement groups
students['High Initial Engagement'] = students['Engagement Score'].apply(lambda x: 'High' if x > students['Engagement Score'].median() else 'Low')

# Group by cohort and calculate mean engagement over months
cohort_analysis = students.groupby(['Cohort', 'High Initial Engagement'])['Engagement Score'].mean().unstack()

# Plot
cohort_analysis.plot(kind='bar')
plt.title('Engagement Over Time by Initial Engagement Level')
plt.xlabel('Cohort')
plt.ylabel('Mean Engagement Score')
plt.show()

# %% [markdown]
# The graph provides strong visual evidence that students who are highly engaged in the first 30 days are more likely to maintain their engagement levels in the long run.

# %% [markdown]
# ### T-Test for Age Groups:
#
# Hypothesis: Older students have higher engagement scores than younger students.

# %%
from scipy.stats import ttest_ind

# Divide students into younger and older groups (assuming a median split)
median_age = students['Age of Learner'].median()
younger_group = students[students['Age of Learner'] <= median_age]['Engagement Score']
older_group = students[students['Age of Learner'] > median_age]['Engagement Score']

# Perform t-test
t_stat, p_value = ttest_ind(younger_group, older_group)
print(f"T-statistic: {t_stat}, P-value: {p_value}")

# Interpretation
if p_value < 0.05:
    print("Statistically significant difference between age groups.")
else:
    print("No significant difference between age groups.")
# Out:
# T-statistic: -0.11820966627240234, P-value: 0.9059132724069179
# No significant difference between age groups.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting box plots for younger and older groups
plt.figure(figsize=(8, 6))
sns.boxplot(data=[younger_group, older_group], palette='pastel')
plt.xticks([0, 1], ['Younger Group', 'Older Group'])
plt.ylabel('Engagement Score')
plt.title('Engagement Score by Age Group')

# Adding the t-test results as text in the plot
plt.text(0.5, max(max(younger_group), max(older_group)) * 0.95, 
         f"T-statistic: {t_stat:.2f}, P-value: {p_value:.2e}", 
         ha='center', fontsize=12)

plt.show()

# %% [markdown]
# ### Regression Analysis
#
# Hypothesis: Students who have engaged recently have higher overall engagement scores.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Prepare the data
X = students[['Days Since Last Engagement']].values.reshape(-1, 1)
y = students['Engagement Score'].values

# Fit the model
reg_model = LinearRegression()
reg_model.fit(X, y)

# Predictions for plotting
y_pred = reg_model.predict(X)

# Plot
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel('Days Since Last Engagement')
plt.ylabel('Engagement Score')
plt.title('Regression: Days Since Last Engagement vs. Engagement Score')
plt.show()

# %% [markdown]
# The upward slope of the line indicates a positive correlation between days since last engagement and overall engagement score.
#
# The positive slope suggests that as the number of days since last engagement decreases (meaning more recent engagement), the overall engagement score tends to increase.
#
# **The graph shows that students who have engaged more recently tend to have higher overall engagement scores. This aligns with the hypothesis.**

# %% [markdown]
# ### Chi-Square Test for Categorical Data
# Hypothesis: Students who sign up early in the year have higher long-term engagement.
#
# Method: Use a chi-square test to see if there's a significant association between signup month and high/low engagement status.

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
students['High Engagement'] = students['Engagement Score'] > students['Engagement Score'].median()
contingency_table = pd.crosstab(students['SignUp Month'], students['High Engagement'])

# Perform chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi2: {chi2}, P-value: {p}")

# Interpretation
if p < 0.05:
    print("Significant association between signup month and high engagement.")
else:
    print("No significant association between signup month and high engagement.")
# Out:
# Chi2: 127.54243229284808, P-value: 5.46652228690605e-22
# Significant association between signup month and high engagement.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the heatmap for the contingency table
plt.figure(figsize=(10, 6))
sns.heatmap(contingency_table, annot=True, cmap='Blues', fmt="d")
plt.title("High Engagement by Signup Month")
plt.xlabel("High Engagement")
plt.ylabel("Signup Month")

# Displaying chi-square test results on the plot
plt.text(1.5, -0.5, f"Chi2: {chi2:.2f}, P-value: {p:.2e}", ha='center', fontsize=12)

plt.show()
